# %% [markdown]
# # **EDA using bi-variate analysis**

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('ds_salaries.csv')
df.head()
# Out:
#    id  work_year experience_level employment_type                   job_title  \
# 0   0       2020               MI              FT              Data Scientist
# 1   1       2020               SE              FT  Machine Learning Scientist
# 2   2       2020               SE              FT           Big Data Engineer
# 3   3       2020               MI              FT        Product Data Analyst
# 4   4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size
# 0               DE            L
# 1               JP            S
# 2               GB            M
# 3               HN            S
# 4               US            L

# %% [markdown]
# ### Work Year VS Salary

# %% [markdown]
# #### Average in each year

# %%
pd.DataFrame(df.groupby('work_year')['salary'].mean().round())
# Out:
#              salary
# work_year
# 2020       382386.0
# 2021       546677.0
# 2022       158828.0

# %%
sns.barplot(df.groupby('work_year')['salary'].mean().round())
# Out:
# <Axes: xlabel='work_year', ylabel='salary'>

# %% [markdown]
# ### **Experience Level VS Salary**

# %% [markdown]
# #### How salary differs by experience

# %%
pd.DataFrame(df.groupby('experience_level')['salary'].mean().round())
# Out:
#                     salary
# experience_level
# EN                264622.0
# EX                427072.0
# MI                480618.0
# SE                213949.0

# %%
plt.bar(df['experience_level'],df['salary'])
plt.show()

# %% [markdown]
# ### **Job title VS Salary**

# %%
pd.DataFrame(df.groupby('job_title')['salary'].mean().round())
# Out:
#                                              salary
# job_title
# 3D Computer Vision Researcher              400000.0
# AI Scientist                               290571.0
# Analytics Engineer                         175000.0
# Applied Data Scientist                     172400.0
# Applied Machine Learning Scientist         141350.0
# BI Data Analyst                           1902045.0
# Big Data Architect                         125000.0
# Big Data Engineer                          455000.0
# Business Data Analyst                      355000.0
# Cloud Data Engineer                        140000.0
# Computer Vision Engineer                    83500.0
# Computer Vision Software Engineer          100333.0
# Data Analyst                                96605.0
# Data Analytics Engineer                     61750.0
# Data Analytics Lead                        405000.0
# Data Analytics Manager                     127134.0
# Data Architect                             177874.0
# Data Engineer                              179211.0
# Data Engineering Manager                   119800.0
# Data Science Consultant                    122714.0
# Data Science Engineer                       84500.0
# Data Science Manager                      1062599.0
# Data Scientist                             508347.0
# Data Specialist                            165000.0
# Director of Data Engineering               141250.0
# Director of Data Science                   193286.0
# ETL Developer                               50000.0
# Finance Data Analyst                        45000.0
# Financial Data Analyst                     275000.0
# Head of Data                               156400.0
# Head of Data Science                       146719.0
# Head of Machine Learning                  6000000.0
# Lead Data Analyst                          569000.0
# Lead Data Engineer                         140333.0
# Lead Data Scientist                       1101667.0
# Lead Machine Learning Engineer              80000.0
# ML Engineer                               2676667.0
# Machine Learning Developer                 100000.0
# Machine Learning Engineer                  272718.0
# Machine Learning Infrastructure Engineer    97333.0
# Machine Learning Manager                   157000.0
# Machine Learning Scientist                 158412.0
# Marketing Data Analyst                      75000.0
# NLP Engineer                               240000.0
# Principal Data Analyst                     122500.0
# Principal Data Engineer                    328333.0
# Principal Data Scientist                   206714.0
# Product Data Analyst                       235000.0
# Research Scientist                         110494.0
# Staff Data Scientist                       105000.0

# %%
plt.bar(df['job_title'],df['salary'])
plt.show()
