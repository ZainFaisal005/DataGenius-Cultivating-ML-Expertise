# %% [markdown]
# # **Column Transform**

# %%
import pandas as pd

# %%
df = pd.read_csv('ds_salaries.csv')
df.head()
# Out:
#    id  work_year experience_level employment_type                   job_title  \
# 0   0       2020               MI              FT              Data Scientist
# 1   1       2020               SE              FT  Machine Learning Scientist
# 2   2       2020               SE              FT           Big Data Engineer
# 3   3       2020               MI              FT        Product Data Analyst
# 4   4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size
# 0               DE            L
# 1               JP            S
# 2               GB            M
# 3               HN            S
# 4               US            L

# %%
x = df.drop('remote_ratio',axis=1)
y = df['remote_ratio']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y)

# %%
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

transformer = ColumnTransformer(transformers=[
    ('t1', OrdinalEncoder(categories=[['S', 'M', 'L']]), ['company_size']),
    ('t2', OneHotEncoder(sparse=False, drop='first'), ['salary_currency'])
], remainder='passthrough')

# %%
transformer.fit_transform(x_train)
# Out:
# c:\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# array([[1.0, 0.0, 0.0, ..., 86703, 'AU', 'AU'],
#        [1.0, 0.0, 0.0, ..., 76940, 'ES', 'ES'],
#        [0.0, 0.0, 0.0, ..., 95746, 'DE', 'US'],
#        ...,
#        [2.0, 0.0, 0.0, ..., 35590, 'PL', 'PL'],
#        [1.0, 0.0, 0.0, ..., 130000, 'CA', 'CA'],
#        [2.0, 0.0, 0.0, ..., 200000, 'IN', 'US']], dtype=object)
